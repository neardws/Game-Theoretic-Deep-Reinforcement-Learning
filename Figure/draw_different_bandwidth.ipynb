# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Pastel1', 'qualitative', 3)
new_colors = bmap.mpl_colors
# new_colors = ['seashell', 'honeydew', 'lightcyan']

fig_title = ['(a) CR', '(b) AER', '(c) ASR', '(d) AVI', '(e) AST', '(f) AWTT']

labels = ['RA', 'C-DDPG', 'GT-DRL']

colors = ['lightcoral', 'orange', 'lightgreen', 'cornflowerblue', 'darkviolet', 'seashell', 'honeydew', 'lightcyan']
markers = ['*', 'd', 's', '^', '^']
font_size = 45
legend_size = 40
markersize = 30
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Bandwidth (MHz)'
#################################################################### #################################################################
plt.subplot(2, 3, 1)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [5, 10, 15]

ra_cr = [95.93054294143944, 134.51086790226424, 143.42268734771815]
c_ddpg_cr = [141.85772387199765, 189.3817884291086, 200.15024838778064]
gt_drl_cr = [150.84161418641992, 192.94618078442903, 211.3272583682287]

plt.plot(x_vals, ra_cr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, c_ddpg_cr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, gt_drl_cr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(5))
plt.ylim(50, 250)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Edge Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [5, 10, 15]

ra_aer = [5.209302827777778, 9.2852203, 10.552874907777777]
c_ddpg_aer = [12.20102907, 19.525583644444442, 19.616432241111113]
gt_drl_aer = [13.579289576666666, 19.74643246777778, 21.501793925555553]

plt.plot(x_vals, ra_aer, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, c_ddpg_aer, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, gt_drl_aer, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0)


plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(5))
plt.ylim(5, 25)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()

#################################################################### #################################################################
plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Rate', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [5, 10, 15]

ra_asr = [0.3899424314256688, 0.4771684258834328, 0.488338192419825]
c_ddpg_asr = [0.4596874567832941, 0.6212158808933003, 0.6571705158346011]
gt_drl_asr = [0.4914949522887567, 0.6327543424317618, 0.6950629235237173]

plt.plot(x_vals, ra_asr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, c_ddpg_asr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, gt_drl_asr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(5))
plt.ylim(0.3, 0.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################

plt.subplot(2, 3, 4)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Vehicle Interference', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [5, 10, 15]

ra_avi = [8.474907570471489e-07, 9.338237936151689e-07, 1.400858788641586e-06]
c_ddpg_avi = [2.33491174409504e-06, 1.220387610111243e-06, 2.9851029577676342e-06]
gt_drl_avi = [2.113590617292384e-06, 1.349493597897199e-06, 2.113590617292384e-06]

plt.plot(x_vals, ra_avi, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, c_ddpg_avi, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, gt_drl_avi, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0)
plt.gca().yaxis.get_offset_text().set(size=font_size) 

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(5))
plt.ylim(0.5e-6, 3e-6)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Time (s)', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [5, 10, 15]

ra_ast = [2.32716903534919, 2.412005263856542, 2.5046507172565065]
c_ddpg_ast = [3.852694235507528, 3.5172479506681165, 3.2985465548820803]
gt_drl_ast = [3.840427006643332, 3.483885178802758, 3.1951228394967117]

plt.plot(x_vals, ra_ast, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, c_ddpg_ast, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, gt_drl_ast, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0)

plt.grid()
ax = plt.gca()

plt.ylim(2, 4)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
ax.xaxis.set_major_locator(MultipleLocator(5))

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Wired Transmission Time (s)', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [5, 10, 15]

ra_awtt= [0.2324940329361494, 0.30124397996834307, 0.3044658821432051]
c_ddpg_awtt = [0.4192806955896936, 0.4364830084935897, 0.4359101519601766]
gt_drl_awtt = [0.4124537009094523, 0.4243553255849978, 0.4262658477698265]

plt.plot(x_vals, ra_awtt, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, c_ddpg_awtt, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, gt_drl_awtt, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0)


plt.ylim(0.2, 0.5)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(5))
plt.grid()
# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-6.pdf", bbox_inches='tight')
plt.show()
