# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Set3', 'qualitative', 8)
colors = bmap.mpl_colors

colors = colors[3: 8]

fig_title = ['(a) ASR', '(b) CR', '(c) AAP',  '(d) AST', '(e) APT', '(f) PLPM']

labels = ['ORM', 'ORL', 'D4PG', 'MADDPG', 'MAD4PG']

markers = ['^', 'v', 's', '*', 'd']
font_size = 45
legend_size = 40
markersize = 30
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Computation Capability (GHz)'


#################################################################### #################################################################
plt.subplot(2, 3, 1) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Rate', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[1, 10]', '[2, 10]', '[3, 10]', '[4, 10]', '[5, 10]']

d4pg_asr = [0.425634644101543, 0.5484569437531109, 0.6148830263812842, 0.6866849178695869, 0.7281981085116973]
orl_asr = [0.5029865604778497, 0.6147336983573918, 0.6926331508213045, 0.7745146839223496, 0.8086112493777999]
oro_asr = [0.4593081134892982, 0.544318068690891, 0.6224489795918368, 0.7109830761572922, 0.7629517172722748]
maddpg_asr = [0.5684668989547038, 0.652776790158572, 0.7369337979094076, 0.764211050273768, 0.778695868591339]
mad4pg_asr = [0.7392483822797412, 0.7609009457441513, 0.7778247884519661, 0.79940268790443, 0.8076157292185167]

plt.plot(x_vals, oro_asr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[2], label=labels[0], linewidth=5.0)
plt.plot(x_vals, orl_asr, linestyle="-", marker=markers[1], markersize=markersize, color=colors[3], label=labels[1], linewidth=5.0)
plt.plot(x_vals, d4pg_asr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[1], label=labels[2], linewidth=5.0)
plt.plot(x_vals, maddpg_asr, linestyle="-", marker=markers[3], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)
plt.plot(x_vals, mad4pg_asr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[0], label=labels[4], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
# plt.ylim(0.4, 1)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################
plt.subplot(2, 3, 2)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[1, 10]', '[2, 10]', '[3, 10]', '[4, 10]', '[5, 10]']

d4pg_cr = [129.221110459458, 167.4805541916803, 187.46194036441702, 209.14542123640027, 221.70702636372897]
orl_cr = [153.05304731817887, 187.4533018151439, 210.86179027800534, 235.11622064296208, 244.75218932254535]
oro_cr = [139.98976286114987, 166.20893387546403, 189.9893242272003, 216.6570668086642, 231.98136990524944]
maddpg_cr = [173.79181760104353, 198.7565063763204, 224.159600375115, 232.34832495205166, 236.47369393334552]
mad4pg_cr = [225.56422018555912, 231.6689115824836, 236.29971934197548, 242.5817849977679, 244.6787694417725]

plt.plot(x_vals, oro_cr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[2], label=labels[0], linewidth=5.0)
plt.plot(x_vals, orl_cr, linestyle="-", marker=markers[1], markersize=markersize, color=colors[3], label=labels[1], linewidth=5.0)
plt.plot(x_vals, d4pg_cr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[1], label=labels[2], linewidth=5.0)
plt.plot(x_vals, maddpg_cr, linestyle="-", marker=markers[3], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)
plt.plot(x_vals, mad4pg_cr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[0], label=labels[4], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
# plt.ylim(120, 250)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
plt.xticks(x_vals, new_x_index, fontsize=font_size)

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
plt.legend(loc=9, fontsize = legend_size, bbox_to_anchor=(0.5,1.1), ncol=5, borderaxespad = 0., frameon=False) 

# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Achieved Potential', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[1, 10]', '[2, 10]', '[3, 10]', '[4, 10]', '[5, 10]']

d4pg_aer = [13.172780392222222, 17.39142739111111, 18.694508066666664, 21.603698056666666, 22.438693444444446]
orl_aer = [16.62813889333333, 20.129884267777776, 22.893828156666665, 25.488671438888886, 26.547225986666668]
oro_aer = [30.716066294644445, 36.40056890877778, 41.605650240566675, 47.432393690244446, 50.83664474486667]
maddpg_aer = [35.52791621222222, 42.02790790222222, 45.67219643888888, 47.25937102333333, 49.25636605]
mad4pg_aer = [48.4417775, 50.925662754444446, 51.09975162666667, 51.04775916555556, 53.04389569777777]

plt.plot(x_vals, oro_aer, linestyle="-", marker=markers[0], markersize=markersize, color=colors[2], label=labels[0], linewidth=5.0)
plt.plot(x_vals, orl_aer, linestyle="-", marker=markers[1], markersize=markersize, color=colors[3], label=labels[1], linewidth=5.0)
plt.plot(x_vals, d4pg_aer, linestyle="-", marker=markers[2], markersize=markersize, color=colors[1], label=labels[2], linewidth=5.0)
plt.plot(x_vals, maddpg_aer, linestyle="-", marker=markers[3], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)
plt.plot(x_vals, mad4pg_aer, linestyle="-", marker=markers[4], markersize=markersize, color=colors[0], label=labels[4], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.xticks(x_vals, new_x_index, fontsize=font_size)

# plt.ylim(5, 60)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################

plt.subplot(2, 3, 4)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Time (s)', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[3], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[1, 10]', '[2, 10]', '[3, 10]', '[4, 10]', '[5, 10]']

d4pg_ast = [14.3469384475112829, 11.8170200252546156, 10.05113846886262, 9.2923931610939334, 8.4252352014549383]
orl_ast = [13.636441716571351, 10.035559608012518, 8.553675962470829, 7.593679741034775, 7.101329252799269]
oro_ast = [15.247966697809986, 11.584206951604674, 9.814393344919917, 8.633977083320026, 8.026254872365577]
maddpg_ast = [12.11024316248009, 9.738104376148257, 8.508740175360236, 8.130320712157937, 7.9223932960051515]
mad4pg_ast = [8.854987963946284, 8.525113376300554, 8.126553160571394, 7.795001396829091, 7.536281137963912]

plt.plot(x_vals, oro_ast, linestyle="-", marker=markers[0], markersize=markersize, color=colors[2], label=labels[0], linewidth=5.0)
plt.plot(x_vals, orl_ast, linestyle="-", marker=markers[1], markersize=markersize, color=colors[3], label=labels[1], linewidth=5.0)
plt.plot(x_vals, d4pg_ast, linestyle="-", marker=markers[2], markersize=markersize, color=colors[1], label=labels[2], linewidth=5.0)
plt.plot(x_vals, maddpg_ast, linestyle="-", marker=markers[3], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)
plt.plot(x_vals, mad4pg_ast, linestyle="-", marker=markers[4], markersize=markersize, color=colors[0], label=labels[4], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(6.5, 16)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Processing Time (s)', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[1, 10]', '[2, 10]', '[3, 10]', '[4, 10]', '[5, 10]']

d4pg_apt = [3.25401190460810225, 3.3222357397199148, 3.36567904438450766, 3.42564159000280455, 3.46479966386697374]
orl_apt = [4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109]
oro_apt = [4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109]
maddpg_apt = [4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109]
mad4pg_apt = [4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109, 4.617975796018109]

for i in range(len(d4pg_apt)):
    d4pg_apt[i] = d4pg_ast[i] - d4pg_apt[i]
    orl_apt[i] = orl_ast[i] - orl_apt[i]
    oro_apt[i] = oro_ast[i] - oro_apt[i]
    maddpg_apt[i] = maddpg_ast[i] - maddpg_apt[i] 
    mad4pg_apt[i] = mad4pg_ast[i] - mad4pg_apt[i]

plt.plot(x_vals, oro_apt, linestyle="-", marker=markers[0], markersize=markersize, color=colors[2], label=labels[0], linewidth=5.0)
plt.plot(x_vals, orl_apt, linestyle="-", marker=markers[1], markersize=markersize, color=colors[3], label=labels[1], linewidth=5.0)
plt.plot(x_vals, d4pg_apt, linestyle="-", marker=markers[2], markersize=markersize, color=colors[1], label=labels[2], linewidth=5.0)
plt.plot(x_vals, maddpg_apt, linestyle="-", marker=markers[3], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)
plt.plot(x_vals, mad4pg_apt, linestyle="-", marker=markers[4], markersize=markersize, color=colors[0], label=labels[4], linewidth=5.0)

plt.grid()
ax = plt.gca()

plt.ylim(1.5, 12)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.xticks(x_vals, new_x_index, fontsize=font_size)

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Proportion of Local Processing to Migration', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[1, 10]', '[2, 10]', '[3, 10]', '[4, 10]', '[5, 10]']

d4pg_local =       [0.10301144848183172, 0.10457939273270278, 0.11448481831757089, 0.10395719263315077, 0.13491786958685908]
orl_local =        [1, 1, 1, 1, 1]
oro_local =        [0, 0, 0, 0, 0]
maddpg_local =     [0.15201592832254848, 0.10847614307046857, 0.14897959183673465, 0.15216525634644093, 0.12672971627675458]
mad4pg_local =     [0.05303633648581378, 0.01560477849676449, 0.04392732702837228, 0.0791438526630164, 0.0258835241413638]

d4pg_edge =       [0.8969885515181684, 0.8954206072672972, 0.8855151816824289, 0.8960428073668492, 0.8650821304131409]
orl_edge =        [0, 0, 0, 0, 0]
oro_edge =        [1, 1, 1, 1, 1]
maddpg_edge =     [0.8479840716774515, 0.8915238569295314, 0.8510204081632653, 0.8478347436535589, 0.8732702837232453]
mad4pg_edge =     [0.946963663514186, 0.9843952215032354, 0.9560726729716278, 0.9208561473369836, 0.974116475858636]

diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 26

colors = ['white', 'gray']
edgecolor = 'black'

plt.bar(x - width - 6 * small_width, oro_local, width, label='Local', hatch="x", color=colors[0], edgecolor="black")
plt.bar(x - width - 6 * small_width, oro_edge, width, label='Migration', bottom=oro_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] - width - 8 * small_width, oro_local[i]+oro_edge[i]+0.03*1, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width - 1 * small_width, orl_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x - width - 1 * small_width, orl_edge, width, bottom=orl_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] - width + -3 *  small_width, orl_local[i]+orl_edge[i]+0.03*1, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 0 * small_width, d4pg_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x + 0 * small_width, d4pg_edge, width, bottom=d4pg_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] + -2 * small_width, d4pg_local[i]+d4pg_edge[i]+0.03*1, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 4.5 * small_width, maddpg_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x + 4.5 * small_width, maddpg_edge, width, bottom=maddpg_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] + 2.5 * small_width, maddpg_local[i]+maddpg_edge[i]+0.03*1, labels[3], fontsize=label_text_size, rotation=90)


plt.bar(x + 9 * small_width, mad4pg_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x + 9 * small_width, mad4pg_edge, width, bottom=mad4pg_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] + 7 * small_width, mad4pg_local[i]+mad4pg_edge[i]+0.03*1, labels[4], fontsize=label_text_size, rotation=90)



plt.ylim(0, 1.4)  
plt.grid()
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)
plt.legend(fontsize = 35, loc=2)

# plt.ylim(0.2, 0.5)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.xticks(x_vals, new_x_index, fontsize=font_size)


# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-CC.pdf", bbox_inches='tight')
plt.show()
