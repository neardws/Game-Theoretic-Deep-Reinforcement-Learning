# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Pastel1', 'qualitative', 3)
new_colors = bmap.mpl_colors
# new_colors = ['seashell', 'honeydew', 'lightcyan']

fig_title = ['(a) CR', '(b) AER', '(c) ASR', '(d) AVI', '(e) AST', '(f) AWTT']

labels = ['RA', 'C-DDPG', 'GT-DRL']

colors = ['lightcoral', 'orange', 'lightgreen', 'cornflowerblue', 'darkviolet', 'seashell', 'honeydew', 'lightcyan']
markers = ['*', 'd', 's', '^', 'o']
font_size = 45
legend_size = 40
markersize = 20
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Traffic Scenario'
#################################################################### #################################################################
plt.subplot(2, 3, 1)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2]

gt_drl_cr = [192.94618078442903, 192.0150727512253]
c_ddpg_cr = [189.3817884291086, 180.524405611025]
ra_cr = [134.51086790226424, 82.58132394451869]


new_x_index = ['Scenario 1', 'Scenario 2']
diff = 1
x = np.arange(1, 3, 1)

width = diff * 0.15
small_width = diff * 0.03
label_text_size = 32

plt.grid()
plt.bar(x - width - 4 * small_width, ra_cr, width, label=labels[0], hatch="/", color=colors[0], edgecolor=None)
plt.bar(x - width + 4 * small_width, c_ddpg_cr, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=None)
plt.bar(x + 7 * small_width, gt_drl_cr, width, label=labels[2], hatch="x", color=colors[4], edgecolor=None)


ax = plt.gca()
plt.xticks(x_vals, new_x_index, fontsize=font_size)
plt.ylim(0, 200)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Edge Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2]

madr_ga_aaov = [19.74643246777778, 18.839821735555557]
c_ddpg_aaov = [19.525583644444442, 16.846689718888893]
ra_aaov = [9.2852203, 5.635608166666667]


new_x_index = ['Scenario 1', 'Scenario 2']
diff = 1
x = np.arange(1, 3, 1)

width = diff * 0.15
small_width = diff * 0.03
label_text_size = 30

plt.grid()
plt.bar(x - width - 4 * small_width, ra_aaov, width, label=labels[0], hatch="/", color=colors[0], edgecolor=None)
plt.bar(x - width + 4 * small_width, c_ddpg_aaov, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=None)
plt.bar(x + 7 * small_width, madr_ga_aaov, width, hatch="x", label=labels[2], color=colors[4], edgecolor=None)



ax = plt.gca()
plt.xticks(x_vals, new_x_index, fontsize=font_size)
plt.ylim(0, 25)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()

#################################################################### #################################################################
plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Rate', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2]

gt_drl_asr = [0.6327543424317618, 0.6288035247143053]
c_ddpg_asr = [0.6212158808933003, 0.5881866997108632]
ra_asr = [0.4771684258834328, 0.4155154091392136]

new_x_index = ['Scenario 1', 'Scenario 2']
diff = 1
x = np.arange(1, 3, 1)

width = diff * 0.15
small_width = diff * 0.03
label_text_size = 32

plt.grid()
plt.bar(x - width - 4* small_width, ra_asr, width, label=labels[0], hatch="/", color=colors[0], edgecolor=None)
plt.bar(x - width + 4* small_width, c_ddpg_asr, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=None)
plt.bar(x + 7 * small_width, gt_drl_asr, width, hatch="x", label=labels[2], color=colors[4], edgecolor=None)

ax = plt.gca()
plt.xticks(x_vals, new_x_index, fontsize=font_size)
plt.ylim(0, 0.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################

plt.subplot(2, 3, 4)
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)
plt.ylabel('Average Vehicle Interference', fontsize=font_size)
plt.title(fig_title[3], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2]
new_x_index = ['Scenario 1', 'Scenario 2']
# y_vals = [0.0, 20.0, 40.0, 60.0, 80.0, 100.0, 120.0]
# new_y_index = ['0', '20', '40', '60', '80', '100', '120']
gt_drl_ai = [1.349493597897199e-06, 2.0322024650120245e-07]
c_ddpg_ai = [1.220387610111243e-06, 1.799646607515032e-07]
ra_ai = [9.338237936151689e-07, 2.855144239645515e-07]


new_x_index = ['Scenario 1', 'Scenario 2']
diff = 1
x = np.arange(1, 3, 1)

width = diff * 0.15
small_width = diff * 0.03
label_text_size = 32

plt.gca().yaxis.get_offset_text().set(size=font_size) 
plt.grid()
plt.bar(x - width - 4 * small_width, ra_ai, width, label=labels[0], hatch="/", color=colors[0], edgecolor=None)
plt.bar(x - width + 4 * small_width, c_ddpg_ai, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=None)
plt.bar(x + 7 * small_width, gt_drl_ai, width, hatch="x", label=labels[2], color=colors[4], edgecolor=None)

plt.ylim(0, 1.5e-6)  
plt.xticks(x_vals, new_x_index, fontsize=font_size)
# plt.yticks(y_vals, new_y_index, fontsize=font_size)

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)
plt.legend(fontsize = font_size)
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Time (s)', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2]
gt_drl_ast = [3.483885178802758, 3.520822483939125]
c_ddpg_ast = [3.5172479506681165, 3.566698371531533]
ra_ast = [2.412005263856542, 2.6793911560428287]


new_x_index = ['Scenario 1', 'Scenario 2']
diff = 1
x = np.arange(1, 3, 1)

width = diff * 0.15
small_width = diff * 0.03
label_text_size = 32

plt.grid()
plt.bar(x - width - 4 * small_width, ra_ast, width, label=labels[0], hatch="/", color=colors[0], edgecolor=None)
plt.bar(x - width + 4 * small_width, c_ddpg_ast, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=None)
plt.bar(x + 7 * small_width, gt_drl_ast, width, hatch="x", label=labels[2], color=colors[4], edgecolor=None)

ax = plt.gca()
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.ylim(0, 4)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小

plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Wired Transmission Time (s)', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title

x_vals = [1, 2]
gt_drl_awtt = [0.4243553255849978, 0.4204191180318409]
c_ddpg_awtt = [0.4364830084935897, 0.4179393435092018]
ra_awtt = [0.30124397996834307, 0.2543838191636233]


new_x_index = ['Scenario 1', 'Scenario 2']
diff = 1
x = np.arange(1, 3, 1)

width = diff * 0.15
small_width = diff * 0.03
label_text_size = 32

plt.grid()
plt.bar(x - width - 4 * small_width, ra_awtt, width, label=labels[0], hatch="/", color=colors[0], edgecolor=None)
plt.bar(x - width + 4 * small_width, c_ddpg_awtt, width, label=labels[1], hatch="\\", color=colors[2], edgecolor=None)
plt.bar(x + 7 * small_width, gt_drl_awtt, width, hatch="x", label=labels[2], color=colors[4], edgecolor=None)


plt.ylim(0, 0.5)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
ax = plt.gca()
plt.xticks(x_vals, new_x_index, fontsize=font_size)

# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-5.pdf", bbox_inches='tight')
plt.show()
