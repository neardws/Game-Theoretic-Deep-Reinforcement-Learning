# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Set3', 'qualitative', 8)
colors = bmap.mpl_colors

colors = colors[3: 8]

fig_title = ['(a) ASR', '(b) CR', '(c) AAP',  '(d) AST', '(e) APT', '(f) PLPM']

labels = ['ORM', 'ORL', 'D4PG', 'MADDPG', 'MAD4PG']

markers = ['s', '^', '*', 'd']
font_size = 45
legend_size = 40
markersize = 30
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Traffic Scenario'

x_vals = [1, 2, 3, 4]
new_x_index = ['No. 1', 'No. 2', 'No. 3', 'No. 4']

#################################################################### #################################################################
ax1 = plt.subplot(2, 3, 1) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Rate', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title

d4pg_asr = [0.6259048091224593, 0.6148830263812842, 0.6311027568922305, 0.6246067985794014]
orl_asr = [0.6938522558254836, 0.6926331508213045, 0.6912280701754387, 0.6950786402841199]
oro_asr = [0.6225656916212196, 0.6224489795918368, 0.6177017543859649, 0.618064434297311]
maddpg_asr = [0.73601883986118, 0.7369337979094076, 0.7266165413533835, 0.7125570776255707]
mad4pg_asr = [0.7755081804660386, 0.7778247884519661, 0.7705263157894737, 0.7611872146118722]


diff = 1
x = np.arange(1, 5, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 30

edgecolor = "gray"

plt.bar(x - width - 6 * small_width, oro_asr, width, label=labels[0], hatch="/", color=colors[2], edgecolor=edgecolor)
plt.bar(x - width - 1 * small_width, orl_asr, width, label=labels[1], hatch="\\", color=colors[3], edgecolor=edgecolor)
plt.bar(x + 0 * small_width, d4pg_asr, width, label=labels[2], hatch="-", color=colors[1], edgecolor=edgecolor)
plt.bar(x + 4.5 * small_width, maddpg_asr, width, label=labels[3], hatch="+", color=colors[4], edgecolor=edgecolor)
plt.bar(x + 9 * small_width, mad4pg_asr, width, label=labels[4], hatch="x", color=colors[0], edgecolor=edgecolor)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
# plt.ylim(0, 0.8)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################
ax2 = plt.subplot(2, 3, 2)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title

d4pg_cr = [191.19698760604712, 187.46194036441702, 192.6893084259221, 190.99727502201952]
orl_cr = [210.8997425562052, 210.86179027800534, 210.0533057757515, 211.50769716179911]
oro_cr = [189.85285697897723, 189.9893242272003, 188.40909906386173, 188.76924494983854]
maddpg_cr = [223.94343780703292, 224.159600375115, 221.14474803146612, 217.32664158639764]
mad4pg_cr = [235.36277678590744, 236.29971934197548, 233.86770573896348, 231.5085443516751]

diff = 1
x = np.arange(1, 5, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 30


plt.bar(x - width - 6 * small_width, oro_cr, width, label=labels[0], hatch="/", color=colors[2], edgecolor=edgecolor)
plt.bar(x - width - 1 * small_width, orl_cr, width, label=labels[1], hatch="\\", color=colors[3], edgecolor=edgecolor)
plt.bar(x + 0 * small_width, d4pg_cr, width, label=labels[2], hatch="-", color=colors[1], edgecolor=edgecolor)
plt.bar(x + 4.5 * small_width, maddpg_cr, width, label=labels[3], hatch="+", color=colors[4], edgecolor=edgecolor)
plt.bar(x + 9 * small_width, mad4pg_cr, width, label=labels[4], hatch="x", color=colors[0], edgecolor=edgecolor)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(0, 250)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
#################################################################### #################################################################
ax3 = plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Achieved Potential', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title

d4pg_aer = [20.727296444444445, 18.694508066666664, 19.25075514, 19.929839672222222]
orl_aer = [22.849007025555554, 22.893828156666665, 22.563938585555558, 22.785328323333335]
oro_aer = [41.710342541555555, 41.605650240566675, 41.2418666295111, 41.21795911051111]
maddpg_aer = [45.16864029111112, 45.67219643888888, 46.808465883333334, 45.385915607777775]
mad4pg_aer = [50.910570952222216, 51.09975162666667, 51.33818466666667, 50.014747167777784]

diff = 1
x = np.arange(1, 5, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 30

plt.bar(x - width - 6 * small_width, oro_aer, width, label=labels[0], hatch="/", color=colors[2], edgecolor=edgecolor)
plt.bar(x - width - 1 * small_width, orl_aer, width, label=labels[1], hatch="\\", color=colors[3], edgecolor=edgecolor)
plt.bar(x + 0 * small_width, d4pg_aer, width, label=labels[2], hatch="-", color=colors[1], edgecolor=edgecolor)
plt.bar(x + 4.5 * small_width, maddpg_aer, width, label=labels[3], hatch="+", color=colors[4], edgecolor=edgecolor)
plt.bar(x + 9 * small_width, mad4pg_aer, width, label=labels[4], hatch="x", color=colors[0], edgecolor=edgecolor)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(0, 55)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# ax1.legend_.remove()
# ax3.legend_.remove()
ax2.legend(loc=9, fontsize = legend_size, bbox_to_anchor=(0.5,1.1), ncol=5, borderaxespad = 0., frameon=False) 


#################################################################### #################################################################

plt.subplot(2, 3, 4)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Service Time (s)', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[3], fontsize=font_size, y=-0.2)     # 图的title

d4pg_ast = [10.07737369388711, 10.05113846886262, 10.1046668619762032, 10.0998442603698764]
orl_ast = [8.582911529895949, 8.553675962470829, 8.76631204830207, 8.678785020372326]
oro_ast = [9.82907267965019, 9.814393344919917, 9.9636327246244, 9.96960346892417]
maddpg_ast = [8.520683466395074, 8.508740175360236, 8.745107944526428, 8.866818449967903]
mad4pg_ast = [8.260814124365462, 8.126553160571394, 8.384310827320864, 8.436267032423986]

diff = 1
x = np.arange(1, 5, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 30

plt.bar(x - width - 6 * small_width, oro_ast, width, label=labels[0], hatch="/", color=colors[2], edgecolor=edgecolor)
plt.bar(x - width - 1 * small_width, orl_ast, width, label=labels[1], hatch="\\", color=colors[3], edgecolor=edgecolor)
plt.bar(x + 0 * small_width, d4pg_ast, width, label=labels[2], hatch="-", color=colors[1], edgecolor=edgecolor)
plt.bar(x + 4.5 * small_width, maddpg_ast, width, label=labels[3], hatch="+", color=colors[4], edgecolor=edgecolor)
plt.bar(x + 9 * small_width, mad4pg_ast, width, label=labels[4], hatch="x", color=colors[0], edgecolor=edgecolor)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(0, 11)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Processing Time (s)', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title

d4pg_apt = [3.3570221337188745, 3.36567904438450766, 3.37780139418957454, 3.39097592787144164]
orl_apt = [4.629998827613554, 4.61797579601811, 4.802169223240746, 4.830303181791628]
oro_apt = [4.629998827613554, 4.61797579601811, 4.802169223240746, 4.830303181791628]
maddpg_apt = [4.629998827613553, 4.617975796018109, 4.802169223240744, 4.830303181791626]
mad4pg_apt = [4.629998827613553, 4.617975796018109, 4.802169223240744, 4.830303181791626]

for i in range(len(d4pg_apt)):
    d4pg_apt[i] = d4pg_ast[i] - d4pg_apt[i]
    orl_apt[i] = orl_ast[i] - orl_apt[i]
    oro_apt[i] = oro_ast[i] - oro_apt[i]
    maddpg_apt[i] = maddpg_ast[i] - maddpg_apt[i]
    mad4pg_apt[i] = mad4pg_ast[i] - mad4pg_apt[i]

diff = 1
x = np.arange(1, 5, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 30

plt.bar(x - width - 6 * small_width, oro_apt, width, label=labels[0], hatch="/", color=colors[2], edgecolor=edgecolor)
plt.bar(x - width - 1 * small_width, orl_apt, width, label=labels[1], hatch="\\", color=colors[3], edgecolor=edgecolor)
plt.bar(x + 0 * small_width, d4pg_apt, width, label=labels[2], hatch="-", color=colors[1], edgecolor=edgecolor)
plt.bar(x + 4.5 * small_width, maddpg_apt, width, label=labels[3], hatch="+", color=colors[4], edgecolor=edgecolor)
plt.bar(x + 9 * small_width, mad4pg_apt, width, label=labels[4], hatch="x", color=colors[0], edgecolor=edgecolor)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(0, 7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.xticks(x_vals, new_x_index, fontsize=font_size)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Proportion of Local Processing to Migration', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title


d4pg_local =       [0.10919682697074859, 0.11448481831757089, 0.12067669172932324, 0.11892440385591066]
orl_local =        [1, 1, 1, 1]
oro_local =        [0, 0, 0, 0]
maddpg_local =     [0.16551809618244914, 0.14897959183673465, 0.10709273182957388, 0.1368848300355149]
mad4pg_local =     [0.06717897868120966, 0.04392732702837228, 0.021729323308270623, 0.06308980213089797]

d4pg_edge =       [0.8908031730292514, 0.8855151816824289, 0.8793233082706766, 0.8810755961440891]
orl_edge =        [0, 0, 0, 0]
oro_edge =        [1, 1, 1, 1]
maddpg_edge =     [0.8344819038175508, 0.8510204081632653, 0.8929072681704261, 0.8631151699644851]
mad4pg_edge =     [0.9328210213187903, 0.9560726729716278, 0.9782706766917293, 0.9369101978691019]

diff = 1
x = np.arange(1, 5, 1)

width = diff * 0.10
small_width = diff * 0.03
label_text_size = 30

bmap = brewer2mpl.get_map('Pastel1', 'qualitative', 8)
colors = bmap.mpl_colors
colors = colors[2:4]

colors = ['white', 'gray']

plt.bar(x - width - 6 * small_width, oro_local, width, label='Local', hatch="x", color=colors[0], edgecolor="black")
plt.bar(x - width - 6 * small_width, oro_edge, width, label='Migration', bottom=oro_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] - width - 8 * small_width, oro_local[i]+oro_edge[i]+0.03*1, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width - 1 * small_width, orl_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x - width - 1 * small_width, orl_edge, width, bottom=orl_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] - width + -3 *  small_width, orl_local[i]+orl_edge[i]+0.03*1, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 0 * small_width, d4pg_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x + 0 * small_width, d4pg_edge, width, bottom=d4pg_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] + -2 * small_width, d4pg_local[i]+d4pg_edge[i]+0.03*1, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 4.5 * small_width, maddpg_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x + 4.5 * small_width, maddpg_edge, width, bottom=maddpg_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] + 2.5 * small_width, maddpg_local[i]+maddpg_edge[i]+0.03*1, labels[3], fontsize=label_text_size, rotation=90)


plt.bar(x + 9 * small_width, mad4pg_local, width, hatch="x", color=colors[0], edgecolor="black")
plt.bar(x + 9 * small_width, mad4pg_edge, width, bottom=mad4pg_local, hatch="-", color=colors[1], edgecolor="black")

for i in range(len(x_vals)):
    plt.text(x[i] + 7 * small_width, mad4pg_local[i]+mad4pg_edge[i]+0.03*1, labels[4], fontsize=label_text_size, rotation=90)

plt.ylim(0, 1.4)  
plt.grid()
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)
plt.legend(fontsize = 35, loc=2)

# plt.ylim(0.2, 0.5)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.xticks(x_vals, new_x_index, fontsize=font_size)


# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-TS.pdf", bbox_inches='tight')
plt.show()
